# %%
import pandas as pd

DonegalMonthlydf = pd.read_csv('C:/Users./BYO User/UCD Data Project/Downloads for Data Project/DonegalMonthly.csv', skiprows=19, sep = '\s*,\s*', engine = 'python')
WestmeathMonthlydf = pd.read_csv('C:/Users./BYO User/UCD Data Project/Downloads for Data Project/WestmeathMonthly.csv', skiprows=19, sep = '\s*,\s*', engine = 'python')
MayoMonthlydf = pd.read_csv('C:/Users./BYO User/UCD Data Project/Downloads for Data Project/MayoMonthly.csv', skiprows=19, sep = '\s*,\s*', engine = 'python')
CorkMonthlydf = pd.read_csv('C:/Users./BYO User/UCD Data Project/Downloads for Data Project/CorkMonthly.csv', skiprows=19, sep = '\s*,\s*', engine = 'python')
DublinMonthlydf = pd.read_csv('C:/Users./BYO User/UCD Data Project/Downloads for Data Project/DublinMonthly.csv', skiprows=19, sep = '\s*,\s*', engine = 'python')

# %%
DonegalMonthlydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 808 entries, 0 to 807
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    808 non-null    int64
#  1   month   808 non-null    int64
#  2   meant   808 non-null    float64
#  3   maxtp   808 non-null    float64
#  4   mintp   808 non-null    float64
#  5   mnmax   808 non-null    float64
#  6   mnmin   808 non-null    float64
#  7   rain    808 non-null    float64
#  8   gmin    808 non-null    float64
#  9   wdsp    807 non-null    float64
#  10  maxgt   793 non-null    float64
#  11  sun     668 non-null    float64
# dtypes: float64(10), int64(2)
# memory usage: 75.9 KB

# %%
WestmeathMonthlydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    872 non-null    int64
#  1   month   872 non-null    int64
#  2   meant   872 non-null    float64
#  3   maxtp   872 non-null    float64
#  4   mintp   872 non-null    float64
#  5   mnmax   872 non-null    float64
#  6   mnmin   872 non-null    float64
#  7   rain    872 non-null    float64
#  8   gmin    871 non-null    float64
#  9   wdsp    870 non-null    float64
#  10  maxgt   868 non-null    float64
#  11  sun     684 non-null    float64
# dtypes: float64(10), int64(2)
# memory usage: 81.9 KB

# %%
MayoMonthlydf
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain  gmin  wdsp  maxgt  \
# 0    1996      8   13.4   20.4    7.3   16.6   10.3  109.4   5.3   8.3   34.0
# 1    1996     10    9.7    NaN    NaN   12.5    7.0    NaN   NaN   NaN    NaN
# 2    1996     11    5.0    NaN    NaN    7.6    2.5    NaN   NaN   NaN    NaN
# 3    1996     12    3.1   10.7   -4.0    5.2    1.1    NaN  -5.3   9.4   48.0
# 4    1997      1    3.4   10.7   -3.9    5.2    1.6   26.0  -5.2   8.0   40.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...    ...
# 306  2022      4    8.2   16.3   -0.7   12.0    4.4   77.2  -2.9   9.1   53.0
# 307  2022      5   11.3   18.6    4.5   14.8    7.7  101.7   1.6   9.3   38.0
# 308  2022      6   12.3   19.9    6.3   15.7    8.9  128.8   3.5   8.8   40.0
# 309  2022      7   15.0   27.6    8.6   18.6   11.3   39.8   6.5   7.4   32.0
# 310  2022      8   15.0   27.2    7.9   19.2   10.9   59.4   4.9   7.1   29.0
#
#       sun
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4    42.1
# ..    ...
# 306   NaN
# 307   NaN
# 308   NaN
# 309   NaN
# 310   NaN
#
# [311 rows x 12 columns]

# %%
CorkMonthlydf
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin  rain  gmin  wdsp  maxgt  \
# 0    1962      1    5.5   11.6   -3.8    8.2    2.7   NaN  -6.3  12.8     70
# 1    1962      2    5.3   12.3   -2.7    7.9    2.7   NaN  -4.4  13.6     57
# 2    1962      3    4.2   12.2   -5.4    7.5    0.9   NaN  -7.2  10.3     63
# 3    1962      4    7.7   18.8    0.6   11.2    4.1  68.6  -1.3  11.7     62
# 4    1962      5    9.7   16.1    2.3   13.3    6.2  80.7  -0.7  12.0     45
# ..    ...    ...    ...    ...    ...    ...    ...   ...   ...   ...    ...
# 722  2022      4    9.0   15.5   -0.7   12.5    5.5  64.9  -7.9   9.4     39
# 723  2022      5   12.1   18.5    6.6   15.7    8.5  35.7  -1.6   8.9     38
# 724  2022      6   13.4   20.7    6.1   17.0    9.7  84.1   1.2   9.3     41
# 725  2022      7   16.1   26.9    8.4   20.0   12.3  28.1   3.5   8.3     31
# 726  2022      8   17.1   28.3    8.7   21.7   12.4  14.2   3.2   7.9     32
#
#        sun
# 0      NaN
# 1      NaN
# 2      NaN
# 3    201.1
# 4    216.5
# ..     ...
# 722  167.2
# 723  164.4
# 724  133.3
# 725  153.5
# 726  236.3
#
# [727 rows x 12 columns]

# %%
CorkMonthlydf['maxgt'] = CorkMonthlydf['maxgt'].astype(float)
CorkMonthlydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 727 entries, 0 to 726
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    727 non-null    int64
#  1   month   727 non-null    int64
#  2   meant   727 non-null    float64
#  3   maxtp   727 non-null    float64
#  4   mintp   727 non-null    float64
#  5   mnmax   727 non-null    float64
#  6   mnmin   727 non-null    float64
#  7   rain    724 non-null    float64
#  8   gmin    727 non-null    float64
#  9   wdsp    727 non-null    float64
#  10  maxgt   727 non-null    float64
#  11  sun     724 non-null    float64
# dtypes: float64(10), int64(2)
# memory usage: 68.3 KB

# %%
DublinMonthlydf
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin  rain  gmin  wdsp  maxgt  \
# 0    1941     11    6.9   14.0   -3.1    9.9    3.9  67.2  -5.7  12.0    NaN
# 1    1941     12    6.5   12.7   -3.6    9.1    3.9  41.7  -7.6  12.5    NaN
# 2    1942      1    4.3   11.9   -3.1    6.9    1.7  91.9  -9.5  13.1    NaN
# 3    1942      2    2.9   11.6   -4.3    5.8   -0.0  25.8 -10.7   9.0    NaN
# 4    1942      3    6.3   16.2   -6.1    9.4    3.2  76.4  -8.3  10.7    NaN
# ..    ...    ...    ...    ...    ...    ...    ...   ...   ...   ...    ...
# 964  2022      4    7.6   17.3   -3.7   12.5    2.7  28.1  -7.1   9.3   43.0
# 965  2022      5   11.9   19.9    2.3   16.3    7.6  48.4  -1.3   8.8   33.0
# 966  2022      6   13.6   22.6    2.3   17.7    9.5  43.6  -2.1   8.3   33.0
# 967  2022      7   16.3   29.1    6.6   21.0   11.7  29.6   0.0   8.1   33.0
# 968  2022      8   15.9   26.3    6.0   21.3   10.5  34.6   0.9   7.3   30.0
#
#        sun
# 0     56.1
# 1     46.1
# 2     72.8
# 3     51.4
# 4     73.9
# ..     ...
# 964  168.4
# 965  166.9
# 966  163.5
# 967  131.6
# 968  222.0
#
# [969 rows x 12 columns]

# %%
# carve up into 5 subset dataframes using iloc. Each df will be for the time period we want 2001-2021

DonegalMonthlyData = DonegalMonthlydf.iloc[548:800 , 0:13].copy()
WestmeathMonthlyData = WestmeathMonthlydf.iloc[612:864 , 0:13].copy()
MayoMonthlyData = MayoMonthlydf.iloc[52:303 , 0:13].copy()
CorkMonthlyData = CorkMonthlydf.iloc[468:719 , 0:13].copy()
DublinMonthlyData = DublinMonthlydf.iloc[710:961 , 0:13].copy()

# %%
DonegalMonthlyData['Location'] = "Donegal"
WestmeathMonthlyData['Location'] = "Westmeath"
MayoMonthlyData['Location'] = "Mayo"
CorkMonthlyData['Location'] = "Cork"
DublinMonthlyData['Location'] = "Dublin"

# %%
DonegalMonthlyData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 548 to 799
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      252 non-null    int64
#  1   month     252 non-null    int64
#  2   meant     252 non-null    float64
#  3   maxtp     252 non-null    float64
#  4   mintp     252 non-null    float64
#  5   mnmax     252 non-null    float64
#  6   mnmin     252 non-null    float64
#  7   rain      252 non-null    float64
#  8   gmin      252 non-null    float64
#  9   wdsp      251 non-null    float64
#  10  maxgt     252 non-null    float64
#  11  sun       120 non-null    float64
#  12  Location  252 non-null    object
# dtypes: float64(10), int64(2), object(1)
# memory usage: 25.7+ KB

# %%
Dataframes = [DonegalMonthlyData, WestmeathMonthlyData, MayoMonthlyData, CorkMonthlyData, DublinMonthlyData]
 
Weather = pd.concat(Dataframes)
Weather
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin  rain  gmin  wdsp  maxgt  \
# 548  2001      1    4.7    9.4   -1.7    6.7    2.7  61.5  -4.5  15.7   57.0
# 549  2001      2    5.1   11.3   -0.7    7.4    2.9  86.5  -2.5  17.2   58.0
# 550  2001      3    5.3   13.1   -2.5    7.5    3.1  29.4  -4.5  17.4   66.0
# 551  2001      4    7.3   14.9    2.2    9.7    4.9  54.2  -0.2  13.9   57.0
# 552  2001      5   11.3   22.3    3.7   14.2    8.4  34.2   2.2   9.7   58.0
# ..    ...    ...    ...    ...    ...    ...    ...   ...   ...   ...    ...
# 956  2021      8   14.7   21.8    7.1   18.6   10.8  65.3   3.2   7.5   32.0
# 957  2021      9   14.7   22.9    5.0   18.6   10.8  42.0   2.7   7.0   36.0
# 958  2021     10   11.9   20.2    3.6   14.9    8.8  79.8   1.8   8.4   35.0
# 959  2021     11    7.6   16.4   -1.2   10.6    4.7  11.7  -4.0   9.5   39.0
# 960  2021     12    6.5   14.1   -1.4    9.3    3.7  85.8  -5.4   9.6   50.0
#
#        sun Location
# 548   77.7  Donegal
# 549   88.7  Donegal
# 550  125.0  Donegal
# 551  152.0  Donegal
# 552  221.9  Donegal
# ..     ...      ...
# 956  115.2   Dublin
# 957  102.6   Dublin
# 958  111.9   Dublin
# 959   70.3   Dublin
# 960   59.1   Dublin
#
# [1257 rows x 13 columns]

# %%
Weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1257 entries, 548 to 960
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      1257 non-null   int64
#  1   month     1257 non-null   int64
#  2   meant     1257 non-null   float64
#  3   maxtp     1257 non-null   float64
#  4   mintp     1257 non-null   float64
#  5   mnmax     1257 non-null   float64
#  6   mnmin     1257 non-null   float64
#  7   rain      1257 non-null   float64
#  8   gmin      1255 non-null   float64
#  9   wdsp      1256 non-null   float64
#  10  maxgt     1257 non-null   float64
#  11  sun       924 non-null    float64
#  12  Location  1257 non-null   object
# dtypes: float64(10), int64(2), object(1)
# memory usage: 137.5+ KB

# %%
pd.set_option('display.max_rows', 15)

# %%
#have a working concat dataframe 
Weather
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin  rain  gmin  wdsp  maxgt  \
# 548  2001      1    4.7    9.4   -1.7    6.7    2.7  61.5  -4.5  15.7   57.0
# 549  2001      2    5.1   11.3   -0.7    7.4    2.9  86.5  -2.5  17.2   58.0
# 550  2001      3    5.3   13.1   -2.5    7.5    3.1  29.4  -4.5  17.4   66.0
# 551  2001      4    7.3   14.9    2.2    9.7    4.9  54.2  -0.2  13.9   57.0
# 552  2001      5   11.3   22.3    3.7   14.2    8.4  34.2   2.2   9.7   58.0
# ..    ...    ...    ...    ...    ...    ...    ...   ...   ...   ...    ...
# 956  2021      8   14.7   21.8    7.1   18.6   10.8  65.3   3.2   7.5   32.0
# 957  2021      9   14.7   22.9    5.0   18.6   10.8  42.0   2.7   7.0   36.0
# 958  2021     10   11.9   20.2    3.6   14.9    8.8  79.8   1.8   8.4   35.0
# 959  2021     11    7.6   16.4   -1.2   10.6    4.7  11.7  -4.0   9.5   39.0
# 960  2021     12    6.5   14.1   -1.4    9.3    3.7  85.8  -5.4   9.6   50.0
#
#        sun Location
# 548   77.7  Donegal
# 549   88.7  Donegal
# 550  125.0  Donegal
# 551  152.0  Donegal
# 552  221.9  Donegal
# ..     ...      ...
# 956  115.2   Dublin
# 957  102.6   Dublin
# 958  111.9   Dublin
# 959   70.3   Dublin
# 960   59.1   Dublin
#
# [1257 rows x 13 columns]

# %%
# practice with code to convert month number to descriptor

import calendar
Weather['month'] = Weather['month'].apply(lambda x: calendar.month_abbr[x])
Weather
# Out:
#      year month  meant  maxtp  mintp  mnmax  mnmin  rain  gmin  wdsp  maxgt  \
# 548  2001   Jan    4.7    9.4   -1.7    6.7    2.7  61.5  -4.5  15.7   57.0
# 549  2001   Feb    5.1   11.3   -0.7    7.4    2.9  86.5  -2.5  17.2   58.0
# 550  2001   Mar    5.3   13.1   -2.5    7.5    3.1  29.4  -4.5  17.4   66.0
# 551  2001   Apr    7.3   14.9    2.2    9.7    4.9  54.2  -0.2  13.9   57.0
# 552  2001   May   11.3   22.3    3.7   14.2    8.4  34.2   2.2   9.7   58.0
# ..    ...   ...    ...    ...    ...    ...    ...   ...   ...   ...    ...
# 956  2021   Aug   14.7   21.8    7.1   18.6   10.8  65.3   3.2   7.5   32.0
# 957  2021   Sep   14.7   22.9    5.0   18.6   10.8  42.0   2.7   7.0   36.0
# 958  2021   Oct   11.9   20.2    3.6   14.9    8.8  79.8   1.8   8.4   35.0
# 959  2021   Nov    7.6   16.4   -1.2   10.6    4.7  11.7  -4.0   9.5   39.0
# 960  2021   Dec    6.5   14.1   -1.4    9.3    3.7  85.8  -5.4   9.6   50.0
#
#        sun Location
# 548   77.7  Donegal
# 549   88.7  Donegal
# 550  125.0  Donegal
# 551  152.0  Donegal
# 552  221.9  Donegal
# ..     ...      ...
# 956  115.2   Dublin
# 957  102.6   Dublin
# 958  111.9   Dublin
# 959   70.3   Dublin
# 960   59.1   Dublin
#
# [1257 rows x 13 columns]

# %%
Weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1257 entries, 548 to 960
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      1257 non-null   int64
#  1   month     1257 non-null   object
#  2   meant     1257 non-null   float64
#  3   maxtp     1257 non-null   float64
#  4   mintp     1257 non-null   float64
#  5   mnmax     1257 non-null   float64
#  6   mnmin     1257 non-null   float64
#  7   rain      1257 non-null   float64
#  8   gmin      1255 non-null   float64
#  9   wdsp      1256 non-null   float64
#  10  maxgt     1257 non-null   float64
#  11  sun       924 non-null    float64
#  12  Location  1257 non-null   object
# dtypes: float64(10), int64(1), object(2)
# memory usage: 137.5+ KB

# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots()
ax.plot(Weather)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File ~\anaconda3\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 fig,ax=plt.subplots()
# ----> 2 ax.plot(Weather)
#       3 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1634, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
# -> 1634     self.add_line(line)
#    1635 self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1636 return lines
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2283, in _AxesBase.add_line(self, line)
#    2280 if line.get_clip_path() is None:
#    2281     line.set_clip_path(self.patch)
# -> 2283 self._update_line_limits(line)
#    2284 if not line.get_label():
#    2285     line.set_label(f'_child{len(self._children)}')
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2306, in _AxesBase._update_line_limits(self, line)
#    2302 def _update_line_limits(self, line):
#    2303     """
#    2304     Figures out the data limit of the given line, updating self.dataLim.
#    2305     """
# -> 2306     path = line.get_path()
#    2307     if path.vertices.size == 0:
#    2308         return
#
# File ~\anaconda3\lib\site-packages\matplotlib\lines.py:999, in Line2D.get_path(self)
#     997 """Return the `~matplotlib.path.Path` associated with this line."""
#     998 if self._invalidy or self._invalidx:
# --> 999     self.recache()
#    1000 return self._path
#
# File ~\anaconda3\lib\site-packages\matplotlib\lines.py:656, in Line2D.recache(self, always)
#     654     x = self._x
#     655 if always or self._invalidy:
# --> 656     yconv = self.convert_yunits(self._yorig)
#     657     y = _to_unmasked_float_array(yconv).ravel()
#     658 else:
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:264, in Artist.convert_yunits(self, y)
#     262 if ax is None or ax.yaxis is None:
#     263     return y
# --> 264 return ax.yaxis.convert_units(y)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1508, in Axis.convert_units(self, x)
#    1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
# -> 1508     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                  f'units: {x!r}') from e
#    1510 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array(['Jan', 'Feb', 'Mar', ..., 'Oct', 'Nov', 'Dec'], dtype=object)

# %%
max_rain_location = Weather[Weather['Location'] == 'Mayo'].groupby('year')['rain'].sum()

# %%
max_rain_location.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker

plt.bar(Weather['year'],Weather['sun'],align='center')

locator = matplotlib.ticker.MultipleLocator(2)
plt.gca().xaxis.set_major_locator(locator)
formatter = matplotlib.ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)

# shows the current axis limits values
print(plt.axis()) 

plt.axis([2001, 2022, 0, 350]) 

plt.xlabel("Year")
plt.ylabel("Hours Sunshine")
plt.title("Hours of Sunshine Per Year Mayo")

plt.show()
# Out:
# (1999.56, 2022.4399999999998, 0.0, 309.75)

# %%
MayoMonthlyData.plot(kind='line',x='year',y='sun',color='red')
plt.gca().set_xticks(MayoMonthlyData["year"].unique())
ax.xaxis.set_major_locator(mdates.YearLocator(base=1))
ax.margins(x=0) # so that the axis starts at the minimum date
ax.set_xticks(ax.get_xticks()[::5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [102], in <cell line: 3>()
#       1 MayoMonthlyData.plot(kind='line',x='year',y='sun',color='red')
#       2 plt.gca().set_xticks(MayoMonthlyData["year"].unique())
# ----> 3 ax.xaxis.set_major_locator(mdates.YearLocator(base=1))
#       4 ax.margins(x=0) # so that the axis starts at the minimum date
#       5 ax.set_xticks(ax.get_xticks()[::5])
#
# NameError: name 'mdates' is not defined

# %%
is.list(MayoMonthlyData())

inherits(MayoMonthlyData.frame(), "data.frame")  # TRUE
inherits(list(), "MayoMonthlyData.frame")        # FALSE
# Out:
#   Input In [104]
#     is.list(MayoMonthlyData())
#     ^
# SyntaxError: invalid syntax

# %%
MayoMonthlyData['sun'].unique()
# Out:
# array([ 70.9,  93.5,  98. , 124.9, 211.6, 125.9, 120.1, 144.8, 114.2,
#         77.9,  31.7,  72.6,  42.1,  55.9,  98.6, 170.3, 150.9, 116.8,
#        110.2, 118.5, 138.1, 106.2,  53.1,  35.1,  80.3,  61.9, 149.8,
#        166.3, 144.1, 158.7, 107.3, 192.2,  94.7, 102.9,  73.6,  50. ,
#         55.1, 101.6, 144.7, 139.4, 179.7, 165. , 151.2, 134.2, 103.4,
#         96.4,  24.6,  34.4,  37.4,  68.1,  89.5, 144.6, 188. , 124.8,
#        115. , 122.7,  82.6,  61.1,  69.2,  34.1,  43.8,  77.1,  79.8,
#        162.9, 172.3, 186.2, 188.8,  95.1, 115.8,  90.9,  62.2,  29.3,
#         45.2,  63.9, 129.2, 192.5, 217.9, 153. , 154.1, 123.2, 111.9,
#         80.1,  29.1,  32.7,  63.1, 113.4, 181.7, 211.8, 162.7, 110.6,
#         75.1, 106.3, 104.8,  49.3,  39.3,  55.3,  67.9, 109.8, 134.6,
#        186.7, 223. , 145. , 100.4, 123.5,  65.6,  56.3,  86.3, 142.1,
#        190.3, 195.9, 180.3,  97. , 171.4, 106. , 103.9,  93.2,  89.4,
#         89.1,  70.4, 103.7, 180. , 157. , 145.2,  75.3,  67.1,  41.2,
#         49.7,  30.1,  36.5, 108.8, 176. , 174.1,  87.8,  87.9, 122.4,
#        106.7,  34.3,  21.6,  62.9,  74.6, 179.3, 135.5, 164.6, 198.4,
#        112.2,  96.8,  84.3,  55.2,  24.3,  41.5,  49. ,  80.2, 132.1,
#        101.3, 137.3,  92.5, 123.4, 114.9,  80. ,  55.8,  27.8,  38.5,
#         50.5,  91.7, 196.2, 102.7, 136.9,  81.6,  75.5,  69.7,  72.5,
#         44.2,  20.8,  35.2,  64.3, 109.4, 140.5, 191.3,  78.5,  83.2,
#         69.5,  74.7,  89.6,  51.4,  30.7, 112.9,  60.1,  97.9, 117.9,
#         95.4,  89.7,  46.9,  49.2,  41.8,  93.9,  81.7, 201.9, 198.9,
#        122.8,  84.2,  66.6,  96.3,  60.7,  15.5,  18.1,  49.8,  65. ,
#        104.7, 148.9, 103.3, 105.9,  97.2,  61.5,  47.6,  54.5,   nan])

# %%
print(MayoMonthlyData.columns)
MayoMonthlyData.head(2)
# Out:
# Index(['year', 'month', 'meant', 'maxtp', 'mintp', 'mnmax', 'mnmin', 'rain',
#        'gmin', 'wdsp', 'maxgt', 'sun', 'Location'],
#       dtype='object')
#     year  month  meant  maxtp  mintp  mnmax  mnmin  rain  gmin  wdsp  maxgt  \
# 52  2001      1    2.5    8.7   -2.9    4.7    0.4  81.8  -5.3   9.2   46.0
# 53  2001      2    3.8   10.9   -2.5    6.7    0.9  66.1  -7.4   9.2   59.0
#
#      sun Location
# 52  70.9     Mayo
# 53  93.5     Mayo

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(MayoMonthlyData['year'], MayoMonthlyData['sun'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
